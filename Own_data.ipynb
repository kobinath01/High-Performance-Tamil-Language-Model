# %%
pip install datasets

# %%
from datasets import load_dataset

# Step 1: Load the dataset from Hugging Face
# Replace 'dataset_name' with the name of the dataset you want to download
# Optionally specify the split (e.g., 'train', 'test', etc.)
dataset = load_dataset('KisanVaani/agriculture-qa-english-only', split='train')  # e.g., 'imdb', 'train'

# Step 2: Convert the dataset to a pandas DataFrame
df = dataset.to_pandas()

# Step 3: Save the DataFrame as a CSV file
csv_file_path = 'dataset.csv'  # Specify your desired file name and path
df.to_csv(csv_file_path, index=False)

print(f"Dataset saved as {csv_file_path}")
# Out:
# Dataset saved as dataset.csv

# %%
pip install googletrans pandas

# %%
# !pip install googletrans==3.1.0a0

# %%
import pandas as pd
from googletrans import Translator

# Load the dataset
file_path = 'dataset.csv'  # Replace with your file path
dataset = pd.read_csv(file_path)

# Initialize the translator
translator = Translator()

# Translate columns to Tamil
print("Translating to Tamil... This may take time.")
dataset['question'] = dataset['question'].apply(lambda x: translator.translate(x, src='en', dest='ta').text)
dataset['answer'] = dataset['answers'].apply(lambda x: translator.translate(x, src='en', dest='ta').text)

# Save only the Tamil columns to a new CSV file
translated_file_path = 'dataset_tamil.csv'
dataset[['question', 'answer']].to_csv(translated_file_path, index=False, encoding='utf-8')

print(f"Translation complete! File saved as '{translated_file_path}'")
# Out:
# Translating to Tamil... This may take time.
# Translation complete! File saved as 'dataset_tamil.csv'

# %%
import chardet

# Detect file encoding
with open('dataset_tamil_agri.csv', 'rb') as f:
    result = chardet.detect(f.read())
    print(result)
# Out:
# {'encoding': 'ISO-8859-1', 'confidence': 0.73, 'language': ''}

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# Load your dataset with the correct encoding
file_path = 'dataset_tamil_agri.csv'  # Replace with your dataset path
dataset = pd.read_csv(file_path, encoding='ISO-8859-1')  # Use detected encoding

# Split the dataset into train and temp (temporary for validation and test)
train, temp = train_test_split(dataset, test_size=0.3, random_state=42)

# Split temp into validation and test
validation, test = train_test_split(temp, test_size=0.5, random_state=42)

# Save each split to separate CSV files
train.to_csv('train.csv', index=False, encoding='utf-8')
validation.to_csv('validation.csv', index=False, encoding='utf-8')
test.to_csv('test.csv', index=False, encoding='utf-8')

print("Dataset split into train.csv, validation.csv, and test.csv!")
# Out:
# Dataset split into train.csv, validation.csv, and test.csv!

# %%
pip install datasets huggingface_hub
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 480.6/480.6 kB 16.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 12.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.3/179.3 kB 17.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 10.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 18.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2024.10.0
#     Uninstalling fsspec-2024.10.0:
#       Successfully uninstalled fsspec-2024.10.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2024.10.0 requires fsspec==2024.10.0, but you have fsspec 2024.9.0 which is incompatible.
# ...

# %%
from datasets import Dataset, DatasetDict
from huggingface_hub import HfApi, HfFolder

# Set your Hugging Face account details
hf_repo_name = "Kobi-01/tamil_agriculture_QA"  # Replace with your HF username and desired repo name
hf_token = "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"  # Generate and use your token from https://huggingface.co/settings/tokens

# Log in to HF
HfFolder.save_token(hf_token)
api = HfApi()
api.whoami(token=hf_token)

# Load the CSV files
train_dataset = Dataset.from_csv("train.csv")
validation_dataset = Dataset.from_csv("validation.csv")
test_dataset = Dataset.from_csv("test.csv")

# Create a DatasetDict for splits
dataset_dict = DatasetDict({
    "train": train_dataset,
    "validation": validation_dataset,
    "test": test_dataset
})

# Push the dataset to the Hugging Face Hub
dataset_dict.push_to_hub(hf_repo_name)

print(f"Dataset uploaded to: https://huggingface.co/{hf_repo_name}")
# Out:
# ...
# Creating parquet from Arrow format:   0%|          | 0/4 [00:00<?, ?ba/s]
# Dataset uploaded to: https://huggingface.co/Kobi-01/tamil_agriculture_QA

# %%
import chardet

with open("train.csv", "rb") as f:
    result = chardet.detect(f.read())
print(result)
# Out:
# {'encoding': 'utf-8', 'confidence': 0.99, 'language': ''}

# %%
train_dataset = Dataset.from_csv("dataset_tamil_agri1.csv", encoding="utf-8")
# Out:
# Generating train split: 0 examples [00:00, ? examples/s]

# %%
import pandas as pd

# Load the file
df = pd.read_csv("dataset_tamil_agri1.csv", encoding="utf-8")

# Display the first few rows
print(df.head())
# Out:
#                                     question  \
# 0  விவசாயத்தில் பயிர் சுழற்சி ஏன் முக்கியம்?
# 1     மண் அரிப்பைத் தடுக்கும் விவசாயம் என்ன?
# 2                 பயிர் சுழற்சி என்றால் என்ன
# 3          பாசனத்தின் வெவ்வேறு முறைகள் என்ன?
# 4       மண்ணின் ஆரோக்கியம் ஏன் முக்கியமானது?
#
#                                               answer
# 0  இது மண் அரிப்பு மற்றும் குறைவதைத் தடுக்க உதவுக...
# 1                                      பயிர் சுழற்சி
# 2  பயிர் சுழற்சி என்பது ஒரே பகுதியில் பல பருவங்கள...
# 3  மேற்பரப்பு நீர்ப்பாசனம், சொட்டு நீர் பாசனம் மற...
# 4  மண் ஆரோக்கியம் பயிர் வளர்ச்சிக்கும் உற்பத்தித்...

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# Load your dataset with the correct encoding
file_path = 'dataset_tamil_agri1.csv'  # Replace with your dataset path
dataset = pd.read_csv(file_path, encoding='utf-8')  # Use detected encoding

# Split the dataset into train and temp (temporary for validation and test)
train, temp = train_test_split(dataset, test_size=0.3, random_state=42)

# Split temp into validation and test
validation, test = train_test_split(temp, test_size=0.5, random_state=42)

# Save each split to separate CSV files
train.to_csv('train.csv', index=False, encoding='utf-8')
validation.to_csv('validation.csv', index=False, encoding='utf-8')
test.to_csv('test.csv', index=False, encoding='utf-8')

print("Dataset split into train.csv, validation.csv, and test.csv!")
# Out:
# Dataset split into train.csv, validation.csv, and test.csv!

# %%
from datasets import Dataset, DatasetDict
from huggingface_hub import HfApi, HfFolder

# Set your Hugging Face account details
hf_repo_name = "Kobi-01/tamil_agriculture_QA"  # Replace with your HF username and desired repo name
hf_token = "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"  # Generate and use your token from https://huggingface.co/settings/tokens

# Log in to HF
HfFolder.save_token(hf_token)
api = HfApi()
api.whoami(token=hf_token)

# Load the CSV files
train_dataset = Dataset.from_csv("train.csv")
validation_dataset = Dataset.from_csv("validation.csv")
test_dataset = Dataset.from_csv("test.csv")

# Create a DatasetDict for splits
dataset_dict = DatasetDict({
    "train": train_dataset,
    "validation": validation_dataset,
    "test": test_dataset
})

# Push the dataset to the Hugging Face Hub
dataset_dict.push_to_hub(hf_repo_name)

print(f"Dataset uploaded to: https://huggingface.co/{hf_repo_name}")
# Out:
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# ...
# Creating parquet from Arrow format:   0%|          | 0/4 [00:00<?, ?ba/s]
# README.md:   0%|          | 0.00/528 [00:00<?, ?B/s]
# Dataset uploaded to: https://huggingface.co/Kobi-01/tamil_agriculture_QA
